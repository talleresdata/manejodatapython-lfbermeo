# %%
import pandas as pd
import sys
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
#from pandas.tools.plotting import radviz
# %matplotlib inline

# %%
dataFrame = pd.read_json('data/log-course2.json')

# %%
dataFrame
# Out:
#                            accept_language  \
# 0                           es-ES,es;q=0.9
# 1                           es-ES,es;q=0.9
# 2      es-ES,es;q=0.8,en-US;q=0.5,en;q=0.3
# 3      es-ES,es;q=0.8,en-US;q=0.5,en;q=0.3
# 4      es-ES,es;q=0.8,en-US;q=0.5,en;q=0.3
# 5      es-ES,es;q=0.8,en-US;q=0.5,en;q=0.3
# 6      es-ES,es;q=0.8,en-US;q=0.5,en;q=0.3
# 7                           es-ES,es;q=0.9
# 8                           es-ES,es;q=0.9
# 9                           es-ES,es;q=0.9
# 10                          es-ES,es;q=0.9
# 11                          es-ES,es;q=0.9
# 12                          es-ES,es;q=0.9
# 13                          es-ES,es;q=0.9
# 14                          es-ES,es;q=0.9
# 15                          es-ES,es;q=0.9
# 16                          es-ES,es;q=0.9
# 17                          es-ES,es;q=0.9
# 18                          es-ES,es;q=0.9
# 19                          es-ES,es;q=0.9
# 20                          es-ES,es;q=0.9
# ...

# %%
dataFrame.keys()
# Out:
# Index(['accept_language', 'agent', 'context', 'event', 'event_source',
#        'event_type', 'host', 'ip', 'name', 'page', 'referer', 'session',
#        'time', 'username'],
#       dtype='object')

# %%
dataFrame['ip'].unique()
# Out:
# array(['77.111.247.82', '157.100.56.84', '186.68.113.24', ...,
#        '190.63.119.23', '186.178.110.187', '190.152.178.158'],
#       dtype=object)

# %%
len(dataFrame['ip'].unique())
# Out:
# 1874

# %%
dataFrame = dataFrame[['ip', 'event_source']].groupby(['ip'],as_index=False).count()
dataFrame
# Out:
#                    ip  event_source
# 0         10.7.16.120             6
# 1        10.7.240.107             5
# 2      104.197.105.56             1
# 3       104.198.30.11             1
# 4       107.15.37.154             5
# 5       108.54.232.46             6
# 6       121.201.98.53             1
# 7      129.213.67.237             2
# 8      131.196.114.79            33
# 9      131.196.115.66           158
# 10       131.196.13.8             5
# 11      131.196.15.24            59
# 12       131.196.61.5            22
# 13    138.122.110.199             3
# 14     138.185.136.56           312
# 15     138.185.137.15             5
# 16    138.185.138.150             2
# 17     151.20.163.107            27
# 18     157.100.138.30             2
# 19     157.100.224.70             1
# 20    157.100.225.222            74
# 21     157.100.28.146            25
# 22     157.100.52.119             5
# 23      157.100.52.83            14
# 24      157.100.52.84           151
# ...

# %%
dataFrame=dataFrame.sample(70)

# %% [markdown]
# ## Gráfica tomando en cuenta las dirección ip de los usuarios, tomando una muestra de 70

# %%
plt.figure(figsize=(10,15),dpi=100)
plt.barh(dataFrame['ip'].values,dataFrame['event_source'].values)
plt.title("Frecuencia de aparición de ip")
plt.xlabel("Frecuencia")
plt.ylabel("Ip")
# Out:
# Text(0, 0.5, 'Ip')
